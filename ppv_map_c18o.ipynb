# %% [markdown]
# This program plot a 3D scatter for the fitted data

# %%
filename = '../fit_c18o_3_sigma/maps/gauss_c18o_p_vlsr_comp1.fits'

# %%
from astropy.io import fits
from spectral_cube import SpectralCube
import astropy.units as u
import numpy as np
import plotly.graph_objects as go
import numpy as np

# %%
fits.getdata(filename)[0]
data = fits.getdata(filename)[0]
data[data == -1] = np.nan

# %% [markdown]
# Get the range of Galactic longitude and latitude

# %%
from astropy.wcs import WCS

# Your existing code...
# data = fits.getdata(filename)[0]
header = fits.getheader(filename)

# Create a WCS object from the FITS header
wcs = WCS(header).celestial[:2]

# Get the range of pixel coordinates
y_pix = np.arange(data.shape[0])
x_pix = np.arange(data.shape[1])

# Convert pixel coordinates to world coordinates
lon, lat = wcs.all_pix2world(x_pix, y_pix, 0)

# Get the range of world coordinates
lon_range = [lon.min(), lon.max()]
lat_range = [lat.min(), lat.max()]

lon_range, lat_range
# Out:
# ([28.62298927348354, 28.95695343697517],
#  [3.3533184050231117, 3.686651098592828])

# %%
x = np.linspace(
    lon_range[0],
    lon_range[1],
    data.shape[1],
)
y = np.linspace(
    lat_range[0],
    lat_range[1],
    data.shape[0],
)
xv, yv = np.meshgrid(x, y)

# Flatten the arrays for x, y, and z coordinates
x = xv.flatten()
y = yv.flatten()
z = data.flatten()

# %%
fig = go.Figure(
    data=go.Scatter3d(
        x=x,
        y=y,
        z=z,
        mode="markers",
        marker=dict(
            size=4,
            color=z,  # set color to an array/list of desired values
            colorscale="Viridis",  # choose a colorscale
            opacity=1,
            colorbar=dict(title="V_LSR (km/s)"),  # add a colorbar with the title 'Values'
            symbol='circle'
        ),
    )
)
lon_min = lon_range[0]
lon_max = lon_range[1]
tickvals = np.linspace(lon_min, lon_max, num=5)  # adjust as needed
ticktext = [str(round(lon_max - val + lon_min, 2)) for val in tickvals]
print(ticktext)
fig.update_layout(
    scene=dict(
        xaxis_title="Galactic Longitude (degrees)",
        yaxis_title="Galactic Latitude (degrees)",
        zaxis_title="Velocity (km/s)",
        yaxis=dict(range=[lat_range[0], lat_range[1]]),
        xaxis=dict(tickmode="array", tickvals=tickvals, ticktext=ticktext),
        zaxis=dict(range=[3, 9]),
        aspectmode="manual",
        aspectratio=dict(x=1, y=1, z=1),

    ),
    title="Molecular V_LSR 3D Scatter Plot - C18O",
)
fig.show()
import plotly.io as pio
pio.write_html(fig, "output/w40_molecular_c18o.html")
# Out:
# ['28.96', '28.87', '28.79', '28.71', '28.62']
# <div>                            <div id="be7f24e1-6efb-4f1e-a8ae-9c41ef5edbfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be7f24e1-6efb-4f1e-a8ae-9c41ef5edbfd")) {                    Plotly.newPlot(                        "be7f24e1-6efb-4f1e-a8ae-9c41ef5edbfd",                        [{"marker":{"color":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,7.245814323425293,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,7.093557834625244,null,7.166093349456787,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,7.040010452270508,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,5.895134925842285,5.976418972015381,null,null,7.063257694244385,7.042511463165283,7.11477518081665,null,7.176924705505371,7.16172456741333,7.199313640594482,7.174153804779053,7.087860107421875,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,5.870445251464844,null,null,null,7.137773036956787,7.12161922454834,7.233922004699707,7.177900791168213,7.145022869110107,7.102341175079346,7.127910614013672,7.173441410064697,7.126659393310547,7.096527099609375,7.038125038146973,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,6.179158687591553,5.773433208465576,5.829957962036133,5.935302734375,null,null,null,6.976487636566162,7.009632587432861,7.201197147369385,7.094725608825684,7.061450958251953,7.011455059051514,7.030451774597168,7.136509418487549,7.1310954093933105,7.083648681640625,6.994714736938477,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,7.051471710205078,7.198585510253906,7.097379684448242,null,null,6.963046073913574,7.028040409088135,7.030731201171875,7.009688854217529,6.961823463439941,null,null,null,null,7.142557621002197,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,6.987494468688965,7.010866165161133,6.987910270690918,6.941405773162842,null,null,null,null,7.112460136413574,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...
